# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanthsai831/231FA04D11/blob/main/Text_to_Audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a=gTTS(input("Enter any text:"))
# Out:
# Enter any text:dua lipa

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a=gTTS(input("Enter any text:"))
# Out:
# Enter any text:qwertyuioooooooooplkkjjjjjjjjjjjjjjjjjjjjjjjjjjjjhgfdsaZXCVBNM

# %%
a.save("Dua.mp3")

# %%
Audio("Dua.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("Peddi.mp3")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-23aa4f535331> in <cell line: 0>()
# ----> 1 Audio("Peddi.mp3")
#
# /usr/local/lib/python3.11/dist-packages/IPython/lib/display.py in __init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     114         if self.data is not None and not isinstance(self.data, bytes):
#     115             if rate is None:
# --> 116                 raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     117             self.data = Audio._make_wav(data, rate, normalize)
#     118
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.

# %%
# !pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 43.4 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as st

# %%
from pydub import AudioSegment

mp3_file = "/content/lipa.mp3"
wav_file = "/content/lipa.wav"

audio = AudioSegment.from_mp3(mp3_file)
audio.export(wav_file, format="wav")

# %%
import speech_recognition as st

# %%
repo = st.Recognizer()

# %%
with st.AudioFile("/content/lipa.wav") as source:
  audio = repo.record(source)
  print("Transcript:",repo.recognize_google(audio))

# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/text.jpeg"
plt.imshow(Image.open(ip))
plt.axis('off')

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print(text)

# %%
ipp = "/content/Screenshot (2).png"
plt.imshow(Image.open(ipp))
plt.axis('off')

# %%
img = Image.open(ipp)
text = pytesseract.image_to_string(img)
print(text)

# %%
aa=gTTS(text)

# %%
aa.save("text.mp3")

# %%
Audio("text.mp3")

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text:")
Translated = t.translate(text,src='en',dest='te')
print("translated text:",Translated.text)
