# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanthsai831/231FA04D11/blob/main/student_performance_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import  matplotlib.pyplot as plt

# %%
dt = pd.read_csv('/content/student_data.csv')

# %%
dt
# Out:
#      Gender     Race Parental_Education         Lunch Test_Preparation  \
# 0      Male  Group A             Master      Standard              NaN
# 1    Female  Group D        High School      Standard        Completed
# 2      Male  Group E        High School  Free/Reduced        Completed
# 3      Male  Group D           Bachelor  Free/Reduced              NaN
# 4      Male  Group E       Some College      Standard        Completed
# ..      ...      ...                ...           ...              ...
# 195  Female  Group C           Bachelor      Standard              NaN
# 196  Female  Group B           Bachelor  Free/Reduced              NaN
# 197  Female  Group B        High School  Free/Reduced              NaN
# 198    Male  Group B             Master      Standard              NaN
# 199    Male  Group A           Bachelor      Standard              NaN
#
#      Math_Score  Reading_Score  Writing_Score  Attendance  Previous_Grades  \
# 0            57             94             70          93               57
# 1            69             42             90          75               74
# 2            54             90             90          89               67
# 3            66             70             75          82               74
# 4            90             79             75          76               61
# ..          ...            ...            ...         ...              ...
# 195          69             43             93          97               86
# 196          70             51             96          79               97
# 197          63             84             86          96               62
# 198          94             41             76          90               77
# 199          48             66             42          80               54
#
#     Performance
# 0          High
# 1           Low
# 2          High
# 3          High
# 4          High
# ..          ...
# 195         Low
# 196        High
# 197        High
# 198        High
# 199         Low
#
# [200 rows x 11 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dt['Math_Score'].plot(kind='hist', bins=20, title='Math_Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Reading_Score'].plot(kind='hist', bins=20, title='Reading_Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Writing_Score'].plot(kind='hist', bins=20, title='Writing_Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Attendance'].plot(kind='hist', bins=20, title='Attendance')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# dt.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# dt.groupby('Race').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# dt.groupby('Parental_Education').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# dt.groupby('Lunch').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dt.plot(kind='scatter', x='Math_Score', y='Reading_Score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt.plot(kind='scatter', x='Reading_Score', y='Writing_Score', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt.plot(kind='scatter', x='Writing_Score', y='Attendance', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt.plot(kind='scatter', x='Attendance', y='Previous_Grades', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dt['Math_Score'].plot(kind='line', figsize=(8, 4), title='Math_Score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Reading_Score'].plot(kind='line', figsize=(8, 4), title='Reading_Score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Writing_Score'].plot(kind='line', figsize=(8, 4), title='Writing_Score')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Attendance'].plot(kind='line', figsize=(8, 4), title='Attendance')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Race'].value_counts()
#     for x_label, grp in dt.groupby('Gender')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Gender')
# _ = plt.ylabel('Race')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Parental_Education'].value_counts()
#     for x_label, grp in dt.groupby('Race')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Race')
# _ = plt.ylabel('Parental_Education')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Lunch'].value_counts()
#     for x_label, grp in dt.groupby('Parental_Education')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Parental_Education')
# _ = plt.ylabel('Lunch')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Test_Preparation'].value_counts()
#     for x_label, grp in dt.groupby('Lunch')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Lunch')
# _ = plt.ylabel('Test_Preparation')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(dt['Gender'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(dt, x='Math_Score', y='Gender', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(dt['Race'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(dt, x='Math_Score', y='Race', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(dt['Parental_Education'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(dt, x='Math_Score', y='Parental_Education', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(dt['Lunch'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(dt, x='Math_Score', y='Lunch', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
dt.describe()
# Out:
#        Math_Score  Reading_Score  Writing_Score  Attendance  Previous_Grades
# count  200.000000     200.000000     200.000000  200.000000       200.000000
# mean    69.910000      67.320000      70.635000   87.095000        74.825000
# std     17.482278      17.426013      17.266803    7.370727        14.576927
# min     40.000000      40.000000      40.000000   75.000000        50.000000
# 25%     56.000000      51.000000      57.750000   80.750000        62.000000
# 50%     69.000000      68.500000      70.000000   87.000000        74.000000
# 75%     86.000000      80.250000      86.250000   94.000000        88.000000
# max     99.000000      99.000000      99.000000   99.000000        99.000000

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              200 non-null    object
#  1   Race                200 non-null    object
#  2   Parental_Education  200 non-null    object
#  3   Lunch               200 non-null    object
#  4   Test_Preparation    105 non-null    object
#  5   Math_Score          200 non-null    int64
#  6   Reading_Score       200 non-null    int64
#  7   Writing_Score       200 non-null    int64
#  8   Attendance          200 non-null    int64
#  9   Previous_Grades     200 non-null    int64
#  10  Performance         200 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 17.3+ KB

# %%
dt['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Gender'] = l.fit_transform(dt['Gender'])

# %%
dt['Gender'].unique()
# Out:
# array([1, 0])

# %%
dt
# Out:
#      Gender     Race Parental_Education         Lunch Test_Preparation  \
# 0         1  Group A             Master      Standard              NaN
# 1         0  Group D        High School      Standard        Completed
# 2         1  Group E        High School  Free/Reduced        Completed
# 3         1  Group D           Bachelor  Free/Reduced              NaN
# 4         1  Group E       Some College      Standard        Completed
# ..      ...      ...                ...           ...              ...
# 195       0  Group C           Bachelor      Standard              NaN
# 196       0  Group B           Bachelor  Free/Reduced              NaN
# 197       0  Group B        High School  Free/Reduced              NaN
# 198       1  Group B             Master      Standard              NaN
# 199       1  Group A           Bachelor      Standard              NaN
#
#      Math_Score  Reading_Score  Writing_Score  Attendance  Previous_Grades  \
# 0            57             94             70          93               57
# 1            69             42             90          75               74
# 2            54             90             90          89               67
# 3            66             70             75          82               74
# 4            90             79             75          76               61
# ..          ...            ...            ...         ...              ...
# 195          69             43             93          97               86
# 196          70             51             96          79               97
# 197          63             84             86          96               62
# 198          94             41             76          90               77
# 199          48             66             42          80               54
#
#     Performance
# 0          High
# 1           Low
# 2          High
# 3          High
# 4          High
# ..          ...
# 195         Low
# 196        High
# 197        High
# 198        High
# 199         Low
#
# [200 rows x 11 columns]

# %%
dt['Race'].unique()
# Out:
# array(['Group A', 'Group D', 'Group E', 'Group C', 'Group B'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Race'] = l.fit_transform(dt['Race'])

# %%
dt['Race'].unique()
# Out:
# array([0, 3, 4, 2, 1])

# %%
dt
# Out:
#      Gender  Race Parental_Education         Lunch Test_Preparation  \
# 0         1     0             Master      Standard              NaN
# 1         0     3        High School      Standard        Completed
# 2         1     4        High School  Free/Reduced        Completed
# 3         1     3           Bachelor  Free/Reduced              NaN
# 4         1     4       Some College      Standard        Completed
# ..      ...   ...                ...           ...              ...
# 195       0     2           Bachelor      Standard              NaN
# 196       0     1           Bachelor  Free/Reduced              NaN
# 197       0     1        High School  Free/Reduced              NaN
# 198       1     1             Master      Standard              NaN
# 199       1     0           Bachelor      Standard              NaN
#
#      Math_Score  Reading_Score  Writing_Score  Attendance  Previous_Grades  \
# 0            57             94             70          93               57
# 1            69             42             90          75               74
# 2            54             90             90          89               67
# 3            66             70             75          82               74
# 4            90             79             75          76               61
# ..          ...            ...            ...         ...              ...
# 195          69             43             93          97               86
# 196          70             51             96          79               97
# 197          63             84             86          96               62
# 198          94             41             76          90               77
# 199          48             66             42          80               54
#
#     Performance
# 0          High
# 1           Low
# 2          High
# 3          High
# 4          High
# ..          ...
# 195         Low
# 196        High
# 197        High
# 198        High
# 199         Low
#
# [200 rows x 11 columns]

# %%
dt['Parental_Education'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', 'Some College'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Parental_Education'] = l.fit_transform(dt['Parental_Education'])

# %%
dt['Parental_Education'].unique()
# Out:
# array([2, 1, 0, 3])

# %%
dt
# Out:
#      Gender  Race  Parental_Education         Lunch Test_Preparation  \
# 0         1     0                   2      Standard              NaN
# 1         0     3                   1      Standard        Completed
# 2         1     4                   1  Free/Reduced        Completed
# 3         1     3                   0  Free/Reduced              NaN
# 4         1     4                   3      Standard        Completed
# ..      ...   ...                 ...           ...              ...
# 195       0     2                   0      Standard              NaN
# 196       0     1                   0  Free/Reduced              NaN
# 197       0     1                   1  Free/Reduced              NaN
# 198       1     1                   2      Standard              NaN
# 199       1     0                   0      Standard              NaN
#
#      Math_Score  Reading_Score  Writing_Score  Attendance  Previous_Grades  \
# 0            57             94             70          93               57
# 1            69             42             90          75               74
# 2            54             90             90          89               67
# 3            66             70             75          82               74
# 4            90             79             75          76               61
# ..          ...            ...            ...         ...              ...
# 195          69             43             93          97               86
# 196          70             51             96          79               97
# 197          63             84             86          96               62
# 198          94             41             76          90               77
# 199          48             66             42          80               54
#
#     Performance
# 0          High
# 1           Low
# 2          High
# 3          High
# 4          High
# ..          ...
# 195         Low
# 196        High
# 197        High
# 198        High
# 199         Low
#
# [200 rows x 11 columns]

# %%
dt['Lunch'].unique()
# Out:
# array(['Standard', 'Free/Reduced'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Lunch'] = l.fit_transform(dt['Lunch'])

# %%
dt['Lunch'].unique()
# Out:
# array([1, 0])

# %%
dt
# Out:
#      Gender  Race  Parental_Education  Lunch Test_Preparation  Math_Score  \
# 0         1     0                   2      1              NaN          57
# 1         0     3                   1      1        Completed          69
# 2         1     4                   1      0        Completed          54
# 3         1     3                   0      0              NaN          66
# 4         1     4                   3      1        Completed          90
# ..      ...   ...                 ...    ...              ...         ...
# 195       0     2                   0      1              NaN          69
# 196       0     1                   0      0              NaN          70
# 197       0     1                   1      0              NaN          63
# 198       1     1                   2      1              NaN          94
# 199       1     0                   0      1              NaN          48
#
#      Reading_Score  Writing_Score  Attendance  Previous_Grades Performance
# 0               94             70          93               57        High
# 1               42             90          75               74         Low
# 2               90             90          89               67        High
# 3               70             75          82               74        High
# 4               79             75          76               61        High
# ..             ...            ...         ...              ...         ...
# 195             43             93          97               86         Low
# 196             51             96          79               97        High
# 197             84             86          96               62        High
# 198             41             76          90               77        High
# 199             66             42          80               54         Low
#
# [200 rows x 11 columns]

# %%
dt['Test_Preparation'].unique()
# Out:
# array([nan, 'Completed'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Test_Preparation'] = l.fit_transform(dt['Test_Preparation'])

# %%
dt['Test_Preparation'].unique()
# Out:
# array([1, 0])

# %%
dt
# Out:
#      Gender  Race  Parental_Education  Lunch  Test_Preparation  Math_Score  \
# 0         1     0                   2      1                 1          57
# 1         0     3                   1      1                 0          69
# 2         1     4                   1      0                 0          54
# 3         1     3                   0      0                 1          66
# 4         1     4                   3      1                 0          90
# ..      ...   ...                 ...    ...               ...         ...
# 195       0     2                   0      1                 1          69
# 196       0     1                   0      0                 1          70
# 197       0     1                   1      0                 1          63
# 198       1     1                   2      1                 1          94
# 199       1     0                   0      1                 1          48
#
#      Reading_Score  Writing_Score  Attendance  Previous_Grades Performance
# 0               94             70          93               57        High
# 1               42             90          75               74         Low
# 2               90             90          89               67        High
# 3               70             75          82               74        High
# 4               79             75          76               61        High
# ..             ...            ...         ...              ...         ...
# 195             43             93          97               86         Low
# 196             51             96          79               97        High
# 197             84             86          96               62        High
# 198             41             76          90               77        High
# 199             66             42          80               54         Low
#
# [200 rows x 11 columns]

# %%
dt['Performance'].unique()
# Out:
# array(['High', 'Low'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Performance'] = l.fit_transform(dt['Performance'])

# %%
dt['Performance'].unique()
# Out:
# array([0, 1])

# %%
dt
# Out:
#      Gender  Race  Parental_Education  Lunch  Test_Preparation  Math_Score  \
# 0         1     0                   2      1                 1          57
# 1         0     3                   1      1                 0          69
# 2         1     4                   1      0                 0          54
# 3         1     3                   0      0                 1          66
# 4         1     4                   3      1                 0          90
# ..      ...   ...                 ...    ...               ...         ...
# 195       0     2                   0      1                 1          69
# 196       0     1                   0      0                 1          70
# 197       0     1                   1      0                 1          63
# 198       1     1                   2      1                 1          94
# 199       1     0                   0      1                 1          48
#
#      Reading_Score  Writing_Score  Attendance  Previous_Grades  Performance
# 0               94             70          93               57            0
# 1               42             90          75               74            1
# 2               90             90          89               67            0
# 3               70             75          82               74            0
# 4               79             75          76               61            0
# ..             ...            ...         ...              ...          ...
# 195             43             93          97               86            1
# 196             51             96          79               97            0
# 197             84             86          96               62            0
# 198             41             76          90               77            0
# 199             66             42          80               54            1
#
# [200 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = dt.drop(['Performance'],axis=1)
y = dt['Performance']

# %%
x
# Out:
#      Gender  Race  Parental_Education  Lunch  Test_Preparation  Math_Score  \
# 0         1     0                   2      1                 1          57
# 1         0     3                   1      1                 0          69
# 2         1     4                   1      0                 0          54
# 3         1     3                   0      0                 1          66
# 4         1     4                   3      1                 0          90
# ..      ...   ...                 ...    ...               ...         ...
# 195       0     2                   0      1                 1          69
# 196       0     1                   0      0                 1          70
# 197       0     1                   1      0                 1          63
# 198       1     1                   2      1                 1          94
# 199       1     0                   0      1                 1          48
#
#      Reading_Score  Writing_Score  Attendance  Previous_Grades
# 0               94             70          93               57
# 1               42             90          75               74
# 2               90             90          89               67
# 3               70             75          82               74
# 4               79             75          76               61
# ..             ...            ...         ...              ...
# 195             43             93          97               86
# 196             51             96          79               97
# 197             84             86          96               62
# 198             41             76          90               77
# 199             66             42          80               54
#
# [200 rows x 10 columns]

# %%
dt.corr()
# Out:
#                       Gender      Race  Parental_Education     Lunch  \
# Gender              1.000000  0.117279           -0.110567  0.080582
# Race                0.117279  1.000000           -0.146536 -0.078755
# Parental_Education -0.110567 -0.146536            1.000000  0.015592
# Lunch               0.080582 -0.078755            0.015592  1.000000
# Test_Preparation   -0.030038  0.027577           -0.017990 -0.084717
# Math_Score          0.040714  0.020532           -0.027745 -0.039232
# Reading_Score       0.101827  0.093640           -0.030225 -0.133768
# Writing_Score      -0.023514 -0.020866            0.108471  0.142627
# Attendance          0.042844 -0.081026           -0.073682 -0.031017
# Previous_Grades    -0.035418 -0.063395            0.053023  0.048215
# Performance        -0.010005  0.013333           -0.053742  0.006449
#
#                     Test_Preparation  Math_Score  Reading_Score  \
# Gender                     -0.030038    0.040714       0.101827
# Race                        0.027577    0.020532       0.093640
# Parental_Education         -0.017990   -0.027745      -0.030225
# Lunch                      -0.084717   -0.039232      -0.133768
# Test_Preparation            1.000000    0.041081       0.015322
# Math_Score                  0.041081    1.000000      -0.015757
# Reading_Score               0.015322   -0.015757       1.000000
# Writing_Score              -0.080412   -0.008866       0.113538
# Attendance                  0.009499   -0.068413      -0.018156
# Previous_Grades             0.001119   -0.079608      -0.108503
# Performance                -0.058600   -0.370456      -0.510493
#
#                     Writing_Score  Attendance  Previous_Grades  Performance
# Gender                  -0.023514    0.042844        -0.035418    -0.010005
# Race                    -0.020866   -0.081026        -0.063395     0.013333
# Parental_Education       0.108471   -0.073682         0.053023    -0.053742
# Lunch                    0.142627   -0.031017         0.048215     0.006449
# Test_Preparation        -0.080412    0.009499         0.001119    -0.058600
# Math_Score              -0.008866   -0.068413        -0.079608    -0.370456
# Reading_Score            0.113538   -0.018156        -0.108503    -0.510493
# Writing_Score            1.000000   -0.131880         0.061716    -0.588647
# Attendance              -0.131880    1.000000        -0.012379     0.147252
# Previous_Grades          0.061716   -0.012379         1.000000     0.066070
# Performance             -0.588647    0.147252         0.066070     1.000000

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.50)

# %%
xtest
# Out:
#      Gender  Race  Parental_Education  Lunch  Test_Preparation  Math_Score  \
# 153       1     2                   1      0                 1          43
# 102       0     1                   1      0                 1          74
# 183       1     3                   2      0                 0          96
# 64        1     0                   2      1                 0          58
# 97        0     0                   0      1                 0          65
# ..      ...   ...                 ...    ...               ...         ...
# 134       1     1                   1      1                 0          90
# 27        0     0                   2      1                 1          59
# 96        0     1                   3      0                 0          56
# 66        0     1                   0      1                 1          44
# 108       0     3                   2      1                 0          53
#
#      Reading_Score  Writing_Score  Attendance  Previous_Grades
# 153             91             90          76               67
# 102             80             63          99               67
# 183             86             89          84               54
# 64              52             62          93               94
# 97              61             98          97               94
# ..             ...            ...         ...              ...
# 134             56             69          76               92
# 27              47             72          93               99
# 96              79             82          86               52
# 66              41             40          88               93
# 108             60             63          99               64
#
# [100 rows x 10 columns]

# %%
sns.pairplot(dt, hue='Performance')

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ypred = lr.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.9

# %%
import pickle

# %%
pickle.dump(lr,open('student.pkl','wb'))
