# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanthsai831/231FA04D11/blob/main/text%2Caudio%2Cpicture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install gTTs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Enter any text:"))
# Out:
# Enter any text:hi! hello good morning this is poojitha

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
! pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 33.5 MB/s eta 0:00:00
# ...

# %%
from pydub import AudioSegment
mp3_file = "/content/Doraemon.mp3"
wav_file = "/content/Doraemon.wav"

audio = AudioSegment.from_mp3(mp3_file)
audio.export(wav_file, format="wav")
# Out:
# <_io.BufferedRandom name='/content/Doraemon.wav'>

# %%
import speech_recognition as sr
reco = sr.Recognizer()
with sr.AudioFile("/content/Doraemon.wav") as source:
  audio_data = reco.record(source)
  print("Transcript:",reco.recognize_google(audio_data))
# Out:
# Transcript: Zindagi song

# %%
! pip install pytesseract pillow

# %%
from  PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/quote 2.jpg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extracted Text:",text)
# Out:
# Extracted Text: fe yee
# Lee
# Pie
#
# i #4 fy

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text:")
translated = t.translate(text,src='en',dest='ka')
print("Translated text:",translated.text)
# Out:
# Enter a text:hello
# Translated text: გამარჯობა
